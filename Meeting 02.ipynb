# %% [markdown]
# # Meeting 2
#
# These steps allow us to load and explore datasets from the course. Please note that this notebook only contains the commands that were executed during the video tutorial. Please check out the video to get more context.

# %%
import pandas as pd

# %%
pd.read_excel('class_tiktok/ADCS-2026-class-tiktok_September+14,+2026_11.27.xlsx')

# %%
pd.read_excel('class_tiktok/ADCS-2026-class-tiktok_September+14,+2026_11.27.xlsx', skiprows=[1,])

# %%
survey = pd.read_excel('class_tiktok/ADCS-2026-class-tiktok_September+14,+2026_11.27.xlsx', skiprows=[1,])

# %%
survey

# %%
survey.head()

# %%
survey['StartDate'].max()

# %%
survey['Duration (in seconds)'].describe()

# %%
survey['sted'].value_counts()

# %%
survey.columns

# %%
survey.isna().sum()

# %%
sample_donation = pd.read_json('class_tiktok/donations/2026-09-02_participant=class_survey_1059_source=TikTok.json')

# %%
sample_donation

# %%
tiktok_watch_history = pd.DataFrame(sample_donation['tiktok_watch_history'].iloc[0])

# %%
tiktok_watch_history.head()
